# %%
import sys
print(sys.executable)
# Out:
# /home/marty/.venv/bin/python

# %%
import pandas as pd
import numpy as np

print("pandas version:", pd.__version__)

# create a small DataFrame
df = pd.DataFrame({
    "name": ["Alice", "Bob", "Charlie", "Dana"],
    "score": [88, 92, 79, 95],
    "attempts": [3, 1, 4, 2]
})

print(df)
print("\nAverage score:", df["score"].mean())
print("\nSorted by score:")
print(df.sort_values("score", ascending=False))

# basic filtering
print("\nScores above 85:")
print(df[df["score"] > 85])
# Out:
# pandas version: 3.0.5
#       name  score  attempts
# 0    Alice     88         3
# 1      Bob     92         1
# 2  Charlie     79         4
# 3     Dana     95         2
#
# Average score: 88.5
#
# Sorted by score:
#       name  score  attempts
# 3     Dana     95         2
# 1      Bob     92         1
# 0    Alice     88         3
# 2  Charlie     79         4
#
# Scores above 85:
#     name  score  attempts
# 0  Alice     88         3
# 1    Bob     92         1
# 3   Dana     95         2

# %%
print ("test)")
import pandas as pd
# Out:
# test)
